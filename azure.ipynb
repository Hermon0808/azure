# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('data.csv')
print('URK22CS1194 Hermon Dasari')
df.head()
# Out:
# URK22CS1194 Hermon Dasari
#    Unnamed: 0  Price   Age       KM FuelType    HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000
# 1           1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000
# 2           2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000
# 3           3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000
# 4           4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000
#
#    Doors  Weight  Maintenance
# 0  three    1165        15500
# 1      3    1165        15750
# 2      3    1165        15950
# 3      3    1165        16950
# 4      3    1170        15750

# %%
print('URK22CS1194 Hermon Dasari')
df.describe()
# Out:
# URK22CS1194 Hermon Dasari
#         Unnamed: 0         Price          Age             KM           HP  \
# count  1436.000000   1436.000000  1336.000000    1421.000000  1430.000000
# mean    717.500000  10730.824513    55.672156   68647.239972   101.478322
# std     414.681806   3626.964585    18.589804   37333.023589    14.768255
# min       0.000000   4350.000000     1.000000       1.000000    69.000000
# 25%     358.750000   8450.000000    43.000000   43210.000000    90.000000
# 50%     717.500000   9900.000000    60.000000   63634.000000   110.000000
# 75%    1076.250000  11950.000000    70.000000   87000.000000   110.000000
# max    1435.000000  32500.000000    80.000000  243000.000000   192.000000
#
#           MetColor    Automatic           CC      Weight   Maintenance
# count  1286.000000  1436.000000  1436.000000  1436.00000   1436.000000
# mean      0.674961     0.055710  1566.827994  1072.45961  12730.824513
# ...

# %%
print('URK22CS1194 Hermon Dasari')
df.isna()
# Out:
# URK22CS1194 Hermon Dasari
#       Unnamed: 0  Price    Age     KM  FuelType     HP  MetColor  Automatic  \
# 0          False  False  False  False     False  False     False      False
# 1          False  False  False  False     False  False     False      False
# 2          False  False  False  False     False  False      True      False
# 3          False  False  False  False     False  False     False      False
# 4          False  False  False  False     False  False     False      False
# ...          ...    ...    ...    ...       ...    ...       ...        ...
# 1431       False  False   True  False     False  False     False      False
# 1432       False  False  False   True     False  False     False      False
# 1433       False  False   True  False     False  False     False      False
# 1434       False  False  False   True      True  False     False      False
# 1435       False  False  False  False     False  False     False      False
#
# ...

# %%
print('URK22CS1194 Hermon Dasari')
df.drop_duplicates()
# Out:
# URK22CS1194 Hermon Dasari
#       Unnamed: 0  Price   Age       KM FuelType     HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90.0       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90.0       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90.0       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90.0       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90.0       0.0          0
# ...          ...    ...   ...      ...      ...    ...       ...        ...
# 1431        1431   7500   NaN  20544.0   Petrol   86.0       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86.0       0.0          0
# 1433        1433   8500   NaN  17016.0   Petrol   86.0       0.0          0
# 1434        1434   7250  70.0      NaN      NaN   86.0       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110.0       0.0          0
#
# ...

# %%
print('URK22CS1194 Hermon Dasari')
df.ffill(inplace=True)
# Out:
# URK22CS1194 Hermon Dasari

# %%
print('URK22CS1194 Hermon Dasari')
df.isnull()
# Out:
# URK22CS1194 Hermon Dasari
#       Unnamed: 0  Price    Age     KM  FuelType     HP  MetColor  Automatic  \
# 0          False  False  False  False     False  False     False      False
# 1          False  False  False  False     False  False     False      False
# 2          False  False  False  False     False  False     False      False
# 3          False  False  False  False     False  False     False      False
# 4          False  False  False  False     False  False     False      False
# ...          ...    ...    ...    ...       ...    ...       ...        ...
# 1431       False  False  False  False     False  False     False      False
# 1432       False  False  False  False     False  False     False      False
# 1433       False  False  False  False     False  False     False      False
# 1434       False  False  False  False     False  False     False      False
# 1435       False  False  False  False     False  False     False      False
#
# ...

# %%
print('URK22CS1194 Hermon Dasari')
df2 = pd.read_csv('data.csv',usecols=['Price','KM','Age','HP'])
df2.head()
# Out:
# URK22CS1194 Hermon Dasari
#    Price   Age       KM    HP
# 0  13500  23.0  46986.0  90.0
# 1  13750  23.0  72937.0  90.0
# 2  13950  24.0  41711.0  90.0
# 3  14950  26.0  48000.0  90.0
# 4  13750  30.0  38500.0  90.0

# %%
print('URK22CS1194 Hermon Dasari')
df2.corr()
# Out:
# URK22CS1194 Hermon Dasari
#           Price       Age        KM        HP
# Price  1.000000 -0.878407 -0.574720  0.309902
# Age   -0.878407  1.000000  0.512735 -0.157904
# KM    -0.574720  0.512735  1.000000 -0.335285
# HP     0.309902 -0.157904 -0.335285  1.000000

# %%
import seaborn as sns
print('URK22CS1194 Hermon Dasari')
sns.boxplot(df['Age'])
# Out:
# URK22CS1194 Hermon Dasari
# <Axes: ylabel='Age'>

# %%
print('URK22CS1194 Hermon Dasari')

df2.corr(method='pearson')
# Out:
# URK22CS1194 Hermon Dasari
#           Price       Age        KM        HP
# Price  1.000000 -0.878407 -0.574720  0.309902
# Age   -0.878407  1.000000  0.512735 -0.157904
# KM    -0.574720  0.512735  1.000000 -0.335285
# HP     0.309902 -0.157904 -0.335285  1.000000

# %%
print('URK22CS1194 Hermon Dasari')

df2.corr(method='pearson')
# Out:
# URK22CS1194 Hermon Dasari
#           Price       Age        KM        HP
# Price  1.000000 -0.878407 -0.574720  0.309902
# Age   -0.878407  1.000000  0.512735 -0.157904
# KM    -0.574720  0.512735  1.000000 -0.335285
# HP     0.309902 -0.157904 -0.335285  1.000000
